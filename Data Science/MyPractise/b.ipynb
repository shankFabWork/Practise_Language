# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn import datasets

# iris = datasets.load_iris()
# boston = datasets.load_boston()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv')

# %%
# type(df[['rad']])
df['rad'].value_counts()
# Out:
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: rad, dtype: int64

# %%
# df.info()

# df_corr = df.corr()
# df_corr[['crim']][df_corr[['crim']] > 0.5]
# df_corr

# df.isnull().sum()
# df.isna().sum()

# df[['rad']].value_counts()
# df[['rad']].sort_values(by="rad",ascending=False)
df.groupby('rad').aggr()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7140/1750500739.py in <module>
#      10 # df[['rad']].value_counts()
#      11 # df[['rad']].sort_values(by="rad",ascending=False)
# ---> 12 df.groupby('rad').aggr()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'aggr'

# %%
# df[['crim']].sort_values(by='crim',ascending = False)
# df[['crim']]

# df.columns

# df[['rad']].sort_values(by='rad',ascending = False)
# Out:
#      rad
# 409   24
# 398   24
# 404   24
# 403   24
# 402   24
# ..   ...
# 255    1
# 254    1
# 194    1
# 193    1
# 505    1
#
# [506 rows x 1 columns]

# %%
# df[['rad']].value_counts()
# df[['rad']].value_counts().max()
df.corr()[['medv']].sort_values(by='medv',ascending=False)
# Out:
#              medv
# medv     1.000000
# rm       0.695360
# zn       0.360445
# b        0.333461
# dis      0.249929
# chas     0.175260
# age     -0.376955
# rad     -0.381626
# crim    -0.388305
# nox     -0.427321
# tax     -0.468536
# indus   -0.483725
# ptratio -0.507787
# lstat   -0.737663

# %%
# df[['median_house_value']]
# df[['median_house_value']].describe()
# df.groupby("median_house_value").agg(['min','max'])

# for i in df.columns:
#     print(i)

# from matplotlib import pyplot as plt
# plt.scatter(x=df[['median_income']],y=df[['households']])
# plt.show()

# print(df.columns)

# df.corr()[['medv']][df.corr()[['medv']] > 0.5]
# print(df.corr()[['indus']][df.corr()[['indus']] < -0.5])

# plt.figure(figsize=(10,4))
# for i in df.columns:
#     df.plot(kind='scatter',x='indus',y=i,s=4)
#     plt.show()

# df[['chas']].value_counts()

# plt.figure(figsize=(10,4))
# for i in df.columns:
#     for j in df.columns:
#         df.plot(kind='scatter',x=i,y=j,s=4)
#         plt.show()

# plt.scatter(df['lstat'],df['medv'],c = df['rad'])

from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn import datasets
import pandas as pd

iris = datasets.load_iris()

# print(iris.data)
# print(iris.target)

# iris.data.shape,iris.target.reshape(-1,1)
# np.vstack())

data = iris.data
target = iris.target.reshape(-1,1)

res_data = np.concatenate((data,target),axis = 1)
# pd.DataFrame({"data":data,"target":target})

# res_data
res_df = pd.DataFrame(res_data,columns=["sl","sw","pl","pw","tar"])
res_df
# Out:
#       sl   sw   pl   pw  tar
# 0    5.1  3.5  1.4  0.2  0.0
# 1    4.9  3.0  1.4  0.2  0.0
# 2    4.7  3.2  1.3  0.2  0.0
# 3    4.6  3.1  1.5  0.2  0.0
# 4    5.0  3.6  1.4  0.2  0.0
# ..   ...  ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3  2.0
# 146  6.3  2.5  5.0  1.9  2.0
# 147  6.5  3.0  5.2  2.0  2.0
# 148  6.2  3.4  5.4  2.3  2.0
# 149  5.9  3.0  5.1  1.8  2.0
#
# [150 rows x 5 columns]

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr.fit(data[:,:2],target)
# Out:
# C:\Users\shank\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
# Sepal Length and Sepal Width
plt.scatter(res_df['sl'],res_df['sw'],c=res_df['tar'])

# %%
# from sklearn.metrics import accuracy_score
# accuracy_score(iris.target,lr.predict(iris.data))

from mlxtend.plotting import plot_decision_regions

pdr = plot_decision_regions(data[:,:2],iris.target,clf=lr)

# %%
data[:,:2]
# Out:
# array([[5.1, 3.5],
#        [4.9, 3. ],
#        [4.7, 3.2],
#        [4.6, 3.1],
#        [5. , 3.6],
#        [5.4, 3.9],
#        [4.6, 3.4],
#        [5. , 3.4],
#        [4.4, 2.9],
#        [4.9, 3.1],
#        [5.4, 3.7],
#        [4.8, 3.4],
#        [4.8, 3. ],
#        [4.3, 3. ],
#        [5.8, 4. ],
#        [5.7, 4.4],
#        [5.4, 3.9],
#        [5.1, 3.5],
#        [5.7, 3.8],
#        [5.1, 3.8],
#        [5.4, 3.4],
#        [5.1, 3.7],
#        [4.6, 3.6],
#        [5.1, 3.3],
#        [4.8, 3.4],
#        [5. , 3. ],
#        [5. , 3.4],
#        [5.2, 3.5],
#        [5.2, 3.4],
#        [4.7, 3.2],
#        [4.8, 3.1],
#        [5.4, 3.4],
#        [5.2, 4.1],
#        [5.5, 4.2],
#        [4.9, 3.1],
#        [5. , 3.2],
#        [5.5, 3.5],
#        [4.9, 3.6],
#        [4.4, 3. ],
#        [5.1, 3.4],
#        [5. , 3.5],
#        [4.5, 2.3],
#        [4.4, 3.2],
#        [5. , 3.5],
#        [5.1, 3.8],
#        [4.8, 3. ],
#        [5.1, 3.8],
# ...

# %%
# !pip install mlxtend

# %%
plt.figure(figsize=(20,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
